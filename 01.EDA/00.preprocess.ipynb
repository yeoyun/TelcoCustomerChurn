# %%
import pandas as pd

df = pd.read_csv("../data/telco.csv")
# Out:
#   Customer ID  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV    Male   78       No            Yes      No         No
# 1  7495-OOKFY  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ  Female   80       No            Yes     Yes        Yes
# 5  4412-YLTKF  Female   72       No            Yes      No        Yes
# 6  0390-DCFDQ  Female   76       No            Yes     Yes        Yes
# 7  3445-HXXGF    Male   66       No            Yes     Yes         No
# 8  2656-FMOKZ  Female   70       No            Yes      No        Yes
# 9  2070-FNEXE  Female   77       No            Yes      No        Yes
#
#    Number of Dependents        Country       State  ...  \
# 0                     0  United States  California  ...
# 1                     1  United States  California  ...
# ...

# %%
# 3. 데이터 구조 확인
print("✅ 데이터 shape:", df.shape)
print("\n✅ 컬럼 정보:")
print(df.info())

# 4. 샘플 확인
print("\n✅ 상위 5개 샘플:")
print(df.head())
# Out:
# ✅ 데이터 shape: (7043, 50)
#
# ✅ 컬럼 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 50 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Under 30                           7043 non-null   object
#  4   Senior Citizen                     7043 non-null   object
#  5   Married                            7043 non-null   object
#  6   Dependents                         7043 non-null   object
#  7   Number of Dependents               7043 non-null   int64
#  8   Country                            7043 non-null   object
#  9   State                              7043 non-null   object
#  10  City                               7043 non-null   object
# ...

# %%
# 범주형 변수 목록 추출
cat_cols = df.select_dtypes(include='object').columns.tolist()
cat_cols = [col for col in cat_cols if col not in ['Customer ID', 'Churn Label', 'Customer Status', 'Churn Category', 'Churn Reason']]

# 고유값 수 확인
for col in cat_cols:
    print(f"{col:25} ▶ 고유값: {df[col].nunique()}개 ▶ 예시: {df[col].unique()[:5]}")
# Out:
# Gender                    ▶ 고유값: 2개 ▶ 예시: ['Male' 'Female']
# Under 30                  ▶ 고유값: 2개 ▶ 예시: ['No' 'Yes']
# Senior Citizen            ▶ 고유값: 2개 ▶ 예시: ['Yes' 'No']
# Married                   ▶ 고유값: 2개 ▶ 예시: ['No' 'Yes']
# Dependents                ▶ 고유값: 2개 ▶ 예시: ['No' 'Yes']
# Country                   ▶ 고유값: 1개 ▶ 예시: ['United States']
# State                     ▶ 고유값: 1개 ▶ 예시: ['California']
# City                      ▶ 고유값: 1106개 ▶ 예시: ['Los Angeles' 'Inglewood' 'Whittier' 'Pico Rivera' 'Los Alamitos']
# Quarter                   ▶ 고유값: 1개 ▶ 예시: ['Q3']
# Referred a Friend         ▶ 고유값: 2개 ▶ 예시: ['No' 'Yes']
# Offer                     ▶ 고유값: 5개 ▶ 예시: [nan 'Offer E' 'Offer D' 'Offer C' 'Offer B']
# Phone Service             ▶ 고유값: 2개 ▶ 예시: ['No' 'Yes']
# Multiple Lines            ▶ 고유값: 2개 ▶ 예시: ['No' 'Yes']
# Internet Service          ▶ 고유값: 2개 ▶ 예시: ['Yes' 'No']
# Internet Type             ▶ 고유값: 3개 ▶ 예시: ['DSL' 'Fiber Optic' 'Cable' nan]
# ...

# %%
label_cols = [
    'Gender', 'Under 30', 'Senior Citizen', 'Married', 'Dependents',
    'Referred a Friend', 'Phone Service', 'Multiple Lines', 'Internet Service',
    'Online Security', 'Online Backup', 'Device Protection Plan',
    'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
    'Streaming Music', 'Unlimited Data', 'Paperless Billing'
]

# %%
onehot_cols = [
    'Contract', 'Payment Method', 'Internet Type', 'Offer'
]

# %%
drop_cols = ['Customer ID', 'Country', 'State', 'City', 'Quarter',
             'Customer Status', 'Churn Score', 'Churn Category', 'Churn Reason']
